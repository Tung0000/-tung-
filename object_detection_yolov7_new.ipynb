# %% [markdown]
# <a href="https://colab.research.google.com/github/Tung0000/-tung-/blob/main/object_detection_yolov7_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# !dir
# Out:
# 11\ 3\ signal\ FS\ โจทย์ตอนต้นคาบ
# 28\ 1\ Fourier\ Representations\ of\ Signals\ and\ Linear\ Time\ Invariant\ Systems\
# 6\ 1\ 68
# ai
# Ai
# Ai\ มก
# Algorithm
# Algorithm\ Design\ 27\ 12
# Algorithm\ to\ day
# Armp
# Classroom
# Colab\ Notebooks
# COM\ A
# Com\ ARC
# DATA
# Database
# Data\ communication
# Dataset2
# Date
# Electronic\ C
# Eng
# ENG\ for\ u\ life
# Exmaa
# Final\ Eilc
# Fourier\ 18\ 2
# Fourier\ 4\ 2
# Fourier\ 4\ 3
# OS\ เสียงคาบทุดท้าย
# Project.
# Signal
# Signal\ 17\ 12
# Signal\ 24\ 12
# Signal\ 7\ 1\ 68
# Signal\ FN
# Signal\ odd\ even
# The\ codding\ bug
# งาน\ ai
# จารซ่ง
# พี่ฝ้าย
# วิชา
# สอบ
# สอบปี3
# อาจารย์ที่ดีที่สุด

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/The codding bug

# %% [markdown]
# # สร้าง Fodel The codding bug

# %%
import os
if not os.path.isdir("The codding bug "):
  os.makedirs("The codding bug")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipython-input-1946963966.py in <cell line: 0>()
#       1 import os
#       2 if not os.path.isdir("The codding bug "):
# ----> 3   os.makedirs("The codding bug")
#
# /usr/lib/python3.12/os.py in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: 'The codding bug'

# %%
# %cd The codding bug
# Out:
# /content/gdrive/MyDrive/The codding bug

# %%
# !dir
# Out:
# yolov7	yolov7-w6.pt

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 15.72 MiB/s, done.
# Resolving deltas: 100% (511/511), done.
# Updating files: 100% (108/108), done.

# %%
# %cd yolov7
# Out:
# /content/gdrive/MyDrive/The codding bug/yolov7

# %%
# !dir
# Out:
# 3.jpg			   export.py   pedestrian.mp4	 traced_model.pt
# BMW_320I_2018_black_1.mov  figure      README.md	 train_aux.py
# Car.mp4			   hubconf.py  requirements.txt  train.py
# cfg			   inference   runs		 utils
# data			   LICENSE.md  scripts		 yolov7-w6.pt
# deploy			   models      test.py
# detect.py		   paper       tools

# %% [markdown]
# # **โหลด model yolov7![world-wide-web-origins-how-it-works-and-impact.webp](data:image/webp;base64,...)**

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-w6.pt
# Out:
# --2025-09-05 12:54:10--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-w6.pt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/The codding bug/yolov7

# %%
# !python detect.py --weights yolov7-w6.pt --conf 0.5 --img-size 1280 --source 3.jpg
# Out:
# Namespace(weights=['yolov7-w6.pt'], source='3.jpg', img_size=1280, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 2025-9-5 torch 2.8.0+cu126 CPU
#
# Fusing layers...
# Model Summary: 343 layers, 70394300 parameters, 653820 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 23 cars, Done. (5033.0ms) Inference, (3.3ms) NMS
#  The output with the result is saved in: runs/detect/exp/3.jpg
# Done. (5.219s)

# %%
# !python detect.py --weights yolov7-w6.pt --conf 0.5 --img-size 1280 --source "/content/gdrive/MyDrive/The codding bug/yolov7/Car.mp4"
# Out:
# Namespace(weights=['yolov7-w6.pt'], source='/content/gdrive/MyDrive/The codding bug/yolov7/Car.mp4', img_size=1280, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.8.0+cu126 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov7/detect.py", line 196, in <module>
#     detect()
#   File "/content/yolov7/detect.py", line 34, in detect
#     model = attempt_load(weights, map_location=device)  # load FP32 model
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov7/models/experimental.py", line 252, in attempt_load
#     ckpt = torch.load(w, map_location=map_location)  # load
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1529, in load
# ...

# %%
# !python detect.py --weights yolov7-w6.pt --conf 0.5   --img-size 1280  --source "/content/gdrive/MyDrive/The codding bug/yolov7/pedestrian.mp4"
# Out:
# python3: can't open file '/content/detect.py': [Errno 2] No such file or directory

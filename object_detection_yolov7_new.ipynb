# %% [markdown]
# <a href="https://colab.research.google.com/github/Tung0000/Object-detex-yolov7/blob/main/object_detection_yolov7_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #เชื่อมข้อมูลกับ google.drive

# %%
# !pip list

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# !git clone https://github.com/WongKinYiu/yolov7.git\
cd
# Out:
# Mounted at /content/gdrive
# Cloning into 'cd'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 29.63 MiB/s, done.
# Resolving deltas: 100% (511/511), done.

# %%
# %cd /content/gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive

# %% [markdown]
# # สร้าง Fodel ถัายังไม่มี

# %%
"""
import os
if not os.path.isdir(" "):
  os.makedirs("")
"""
# Out:
# '\nimport os\nif not os.path.isdir("The codding bug "):\n  os.makedirs("The codding bug")\n  '

# %%
# %cd The codding bug
# Out:
# /content/gdrive/MyDrive/The codding bug

# %%
# !dir
# Out:
# yolov7	yolov7-w6.pt

# %% [markdown]
# #โหลด code จาก git hub [github](https://github.com/WongKinYiu/yolov7)  ![GitHub_Invertocat_Logo.svg.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 15.72 MiB/s, done.
# Resolving deltas: 100% (511/511), done.
# Updating files: 100% (108/108), done.

# %%
# %cd yolov7
# Out:
# /content/gdrive/MyDrive/The codding bug/yolov7

# %%
# !dir
# Out:
# 3.jpg			      data	  models	    test.py
# BMW_320I_2018_black_1.mov     deploy	  paper		    tools
# Car2.mp4		      detect.py   pedestrian.mp4    traced_model.pt
# Car.mp4			      export.py   Peoplewalk.mp4    train_aux.py
# cfg			      figure	  README.md	    train.py
# Coco\ plan\ bird\ people.jpg  hubconf.py  requirements.txt  utils
# Coco.png		      inference   runs		    yolov7-w6.pt
# cocotest.jpg		      LICENSE.md  scripts	    yolov7x.pt

# %% [markdown]
# #โหลด model มาใช้       [github] https://github.com/WongKinYiu/yolov7)
#
# ![traffic-detection-night-yolov7-visoai.jpg](data:image/jpeg;base64,...)
#
# > เพิ่มข้อความทั้งย่อหน้าที่ยกมา

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-w6.pt
# Out:
# --2025-09-05 12:54:10--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-w6.pt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/The codding bug/yolov7

# %% [markdown]
# ![traffic-detection-night-yolov7-visoai.jpg](data:image/jpeg;base64,...)#Inferecen ข้อมูล

# %%
# !python detect.py --weights yolov7x.pt --conf 0.4 --img-size 640 --source Car2.mp4 device="cpu"
# Out:
# Namespace(weights=['yolov7x.pt'], source='Car2.mp4', img_size=640, conf_thres=0.4, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 2025-9-5 torch 2.8.0+cu126 CUDA:0 (Tesla T4, 15095.0625MB)
#
# Fusing layers...
# Model Summary: 354 layers, 71311741 parameters, 571965 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 3 cars, 5 motorcycles, Done. (24.8ms) Inference, (166.4ms) NMS
# ...

# %%
# !python detect.py --weights yolov7-w6.pt --conf 0.5 --img-size 1280 --source "/content/gdrive/MyDrive/The codding bug/yolov7/Car.mp4"
# Out:
# Namespace(weights=['yolov7-w6.pt'], source='/content/gdrive/MyDrive/The codding bug/yolov7/Car.mp4', img_size=1280, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.8.0+cu126 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov7/detect.py", line 196, in <module>
#     detect()
#   File "/content/yolov7/detect.py", line 34, in detect
#     model = attempt_load(weights, map_location=device)  # load FP32 model
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov7/models/experimental.py", line 252, in attempt_load
#     ckpt = torch.load(w, map_location=map_location)  # load
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1529, in load
# ...

# %%
# !python detect.py --weights yolov7-w6.pt --conf 0.5   --img-size 1280  --source "/content/gdrive/MyDrive/The codding bug/yolov7/pedestrian.mp4"
# Out:
# python3: can't open file '/content/detect.py': [Errno 2] No such file or directory
